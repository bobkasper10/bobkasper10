# %% [markdown]
# <a href="https://colab.research.google.com/github/bobkasper10/bobkasper10/blob/main/ImportCSV093022_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
import csv

# %%
localFilePath = "/content/sample_data/california_housing_train.csv"

# %%
df = pd.read_csv(localFilePath)

# %%
df.head(10)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
# 5    -114.58     33.63                29.0       1387.0           236.0
# 6    -114.58     33.61                25.0       2907.0           680.0
# 7    -114.59     34.83                41.0        812.0           168.0
# 8    -114.59     33.61                34.0       4789.0          1175.0
# 9    -114.60     34.83                46.0       1497.0           309.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# ...

# %%
df.tail(5)
# Out:
#        median_age  total_rooms  total_bedrooms  population  households  \
# 16995        52.0       2217.0           394.0       907.0       369.0
# 16996        36.0       2349.0           528.0      1194.0       465.0
# 16997        17.0       2677.0           531.0      1244.0       456.0
# 16998        19.0       2672.0           552.0      1298.0       478.0
# 16999        52.0       1820.0           300.0       806.0       270.0
#
#        median_income  median_house_value
# 16995         2.3571            111400.0
# 16996         2.5179             79000.0
# 16997         3.0313            103600.0
# 16998         1.9797             85800.0
# 16999         3.0147             94600.0

# %%
to_drop = ['longitude', 'latitude']

# %%
df.drop(to_drop, inplace = True, axis = 1)

# %%
new_name = {'housing_median_age' : 'median_age'}

# %%
df.rename(columns =new_name, inplace = True)
